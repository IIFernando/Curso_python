# %%
import pandas as pd

sped = pd.read_csv(
    r'/home/fernando/Python/Fiscal/SPED.txt',
    sep="|",                # separador correto do SPED
    header=None,            # o SPED não tem cabeçalho
    engine="python",        # motor mais tolerante que o C
    on_bad_lines="skip"     # ignora linhas problemáticas, se houver
)

#Filtrando coluna do bloco.
# sped = sped[sped[1] == '']

display(sped)
# Out:
#      0     1          2                         3               4        5   \
# 0   NaN  0000        002                         0             NaN      NaN
# 1   NaN  0001          0                       NaN            None     None
# 2   NaN  0110          3                         2               2      NaN
# 3   NaN  0111   11200000                   6000000         1000000  1800000
# 4   NaN  0140  CE0000001  EMPRESA TESTE - PAULISTA  99999999000191       SP
# ..   ..   ...        ...                       ...             ...      ...
# 280 NaN  9900       M810                         2             NaN     None
# 281 NaN  9900       M990                         1             NaN     None
# 282 NaN  9900       9900                        60             NaN     None
# 283 NaN  9990         63                       NaN            None     None
# 284 NaN  9999        308                       NaN            None     None
#
# ...
